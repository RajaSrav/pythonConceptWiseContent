# %% [markdown]
# # Jupyter Note book
#
# - Anaconda Installation
#
# ### about anaconda navigator
#
#     * Anaconda Navigator is a desktop graphical user interface included in Anaconda that allows you to launch applications and easily manage conda packages, environments and channels without the need to use command line commands.
#
# ### difference between Python Idle and Jupyter Notebook
#
# * IDLE full form Integrated Development and Learning Environment
# * IDLE
# * jupyter
#
# - About Jupyter Notebook
# - Using Jupyter Notebook
#     > 1. Code Mode and
#     > 2. Markdown Mode
#
# ### Markdown Mode
#
# - Morkdown using Document preparation
#
# # Single Hash is a Heading (h1)
#
# ## second heading 1 to 6 headings
#
# ### font size
#
# > 1. h1 --> 32 px
# > 2. h2 --> 24 px
# > 3. h3 --> 18.72 px
# > 3. h4 --> 16 px
# > 3. h5 --> 13.28 px
# > 3. h6 --> 10.72 px
#
# **Bold**
# * *Itallic*
# * ***Itallic and Bold***
# * Normal Text
#   * Sublist 1
#   * Sublist 2
#
# ### Order List
#
# > 1. Ordered list element 1
# > 2. Ordered list element 2
#
# ### un order List
#
# - list
# - lists
#
# ### Links
#
# [Name](Link)
#
# [Google](http://google.com)
#
# #### image link
#
# - Exlomiter Symble '!'[ImageName] (image path)
#
# ![Jupyter](raja.png)
#
#
# - []Option 1
# - []Option 2
# - [x]Option 3
#
# I get 10 times more traffic from [Google] [1] than from
# [Yahoo] [2] or [MSN] [3].
#
#   [1]: http://google.com/        "Google"
#   [2]: http://search.yahoo.com/  "Yahoo Search"
#   [3]: http://search.msn.com/    "MSN Search"
#
#
# ### Code by document
#
# - using  quataation `    `
#
# `print("Hellow World")`

# %% [markdown]
# # HTML Using
#
#
# <h1> Headings <h1>
#
#
# <p>I am using Paragraph tag</p>
#
# <p><b>paragraph tag with bold tag</b></p>
#
# <img src="raja.png" style="float:center">
#
# <img src='raja.png' height="150px" width="150px">
#
#
#
# ## HTML List
#
# - Unorderesd List
#     - UL tag with li tag
# - Ordered List
#     - OL tag with li tag
#
# <a href="pyhonimage.png">Click here for advanced</a>
